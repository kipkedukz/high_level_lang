# %%
'''Лабораторная работа №1 Выполнил: ФИО'''
# Out:
# 'Лабораторная работа №1 Выполнил: ФИО'

# %% [markdown]
# <h6> Экран, который вы видите называется Jupyter Notebook, именно в нем будет происходить бОльшая часть нашей с вами работы <br></h6>
# <h2>
# Сегодня мы поговорим о типах данных на языке Python. <br> </h2>

# %% [markdown]
# Но прежде чем говорить о коде, давайте обсудим некоторые правила, которые будут с Вами в течение прохождения этого курса <br>
# Во-первых, не стесняемся пользоваться интернетом. Умение добывать информацию и правильно ее использовать намного важнее, чем зубрить. <br>
# Во-вторых, всю теорию, озвученную в курсе, надо ЗНАТЬ и ПОНИМАТЬ. Понимать значит уметь объяснить,  объяснить, если спросили по-другому, и самое главное уметь применить на практие. <br>
# В-третьих, не стесняемся много спрашивать. Задавать вопросы - это круто. Только вопросы надо правильно формулировать. И еще правило - сначала ищем сами, потом спрашиваем у одногруппников, а потом у меня) <br>

# %% [markdown]
# <b>Теперь о правилах написания кода:</b>
# <li>Код должен быть чистым (адекватное название переменных, если это индекс - то ind, если функция,
#                              должно быть понятно, что она выполняет, не должен занимать лишних строк, содержать пустых переменных и тд. Чистоте кода позже мы посвятим отдельную лекцию )</li>
# <li>Код должен быть понятен Вам, это самое важное правило. Можно взять участок кода в интернете, но нужно детально понимать, что делает каждая его строка </li>
# <li>Мы затронем с вами основные принципы алгоритмов (понятность, массовость, конечность). Вот они должны выполняться абсолюнтно для каждой написанной программы</li>

# %% [markdown]
# <i>А теперь давайте поговорим о теме урока</i>
# <br>
# <b> Типы данных на языке питон</b>
# <ol>
#     <li>Numbers (числа)
#     <li>Strings (строки)
#     <li>Boolean (логический тип данных)
#     <li>Lists (списки)
#     <li>Dictionaries (словари)
#     <li>Tuples (кортежи)
#     <li>Sets (множества)
# </ol>
# <br>
# <br>
# <i>Первые два мы разберем сегодня</i>

# %%
#в питоне есть интересная особенность, 
#не смотря на то, что он является строготипизированным языком программирования, указывать тип данных перед 
#объявлением переменной не обязательно  
number = 3 #это переменная числового типа
text = "Hello world" #Это строковая переменная

# %%
print('Тип переменной number: ', type(number))
print('Тип переменной text: ', type(text))
# Out:
# Тип переменной number:  <class 'int'>
# Тип переменной text:  <class 'str'>

# %%
#как работает assert - то специальная конструкция, 
#позволяющая проверять предположения о значениях произвольных данных в произвольном месте программы.
#В данном случае assert - ы нужны для меня, их нельзя удалять, они нужны для быстрой проверки правильности кода 
assert int(number),  "Переменная не является числом"

# %%
#а тут асерт не прошел 
assert int(text),  "Переменная не является числом"
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-c7f727584e02> in <module>
#       1 #а тут асерт не прошел
# ----> 2 assert int(text),  "Переменная не является числом"
#
# ValueError: invalid literal for int() with base 10: 'Hello world'

# %%
#давайте создадим две переменные типа int и попробуем решить задание с входного контроля 
a = 14
b = 8 
print('изначальные значения переменной a = ',a, ' b = ',b) #кстати print - это вывод. 
#Текст в одинарных кавычках выводится без изменений, без кавычек - выводится значение переменной 
#нам нужно поменять их местами. Во входном контроле было два правильных решения, описанных Вами. 
#первое - ввести дополнительную переменную 
#присвоим ей значение первой переменной, чтобы сохранить его
tmp = a
print('tmp = ',tmp)
#значение переменной а мы уже сохранили, теперь мы можем перезаписать в нее значение переменной b
a = b
print('a = ',a)
#а теперь в переменную b запишем значение временной переменной, в которой в данный момент хранится значение переменной 
print('b = ',b)
b = tmp
# Out:
# изначальные значения переменной a =  14  b =  8
# tmp =  14
# a =  8
# b =  8

# %% [markdown]
# <b>Задание №1</b>

# %%
#а вот и первое задание. 
#давайте попробуем повторить второе решение, предложенное Вами же но уже на Питоне
#Ваша задача поменять местами значения переменных c  =  11 и d = 25 
#объявите две переменные c = 11

# 1)тут должна быть строка кода

#d = 25

# 2)тут должна быть строка кода

#в переменную c запишите сумму переменных c и d

# 3)тут должна быть строка кода

#теперь значению переменной d присвойте разность переменных c и d

# 4)тут должна быть строка кода

#а теперь переменной c присвойте значение разности c и d

# 5)тут должна быть строка кода

# %%
assert((c==25) and (d==11)), "Значения переменных не правильные, попробуй еще раз"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-25-23b55421723d> in <module>
# ----> 1 assert((c==25) and (d==11)), "Значения переменных не правильные, попробуй еще раз"
#
# AssertionError: Значения переменных не правильные, попробуй еще раз

# %%
#Теперь давайте поговорим о строковых переменных 
text1 = "Hello world" #Это строка, строка может записываться в двойных кавычках, 
text2 = 'Здравствуй мир' #а может и в одинарных 
print(text1)
print(text2)
# Out:
# Helo world
# Здравствуй мир

# %%
#Строки можно склеивать 
textsum = text1 + text2
print('Это склейка первой и второй строки ',textsum)
#кстати, можно добавлять кусок строки без объявления его в переменную 
textsum2 = text1 + ' ' + text2
print('Это склейка первой и второй строки с пробелом между ними',textsum2)
#PS Отнимать строки не получится, появится ошибка
# Out:
# Это склейка первой и второй строки  Helo worldЗдравствуй мир
# Это склейка первой и второй строки с пробелом между ними Helo world Здравствуй мир

# %%
#зато можно заменить символ строки с помощью .replace(старое значение, новое значение)
#Например в строке Hello world поменяем о на 9 
print(text1.replace('o', '9'))
#PS эта запись не поменяет значение переменной text1 (думаю это очевидно)
print(text1)
# Out:
# Hel9 w9rld
# Helo world

# %% [markdown]
# <b>Задание №2</b>

# %%
#чтобы поменять значения переменной нужно его присвоить. Это ваше второе задание, 
#поменяйте в переменной text2 символ a на 5, и запишите его в значение text2 (перезапишите значение переменной)
#обязательно использовать функцию replace

# 6)тут должна быть строка кода

# %% [markdown]
# <b>Задание №3</b>

# %%
#кстати, менять можно слова целиком, именно это предстоит Вам с третьем задании
oldtext = "Что такое язык программирования? Это «мостик» между мозгом программиста и компьютера. Языки высокого уровня, к которым относится Python – предполагают, что они ближе к человеческому языку, чем к машинному. В отличие от, например, Ассемблера. А у Python настолько простые и ясные правила, что он приближается к английскому языку. Поэтому часто программирование на языке Python называют «программированием со скоростью мысли». Код на языке Python лаконичен и требует меньше времени на разработку, чем коды на других популярных языках. Самое главное, чтобы у программиста была «мысль» – а осуществить ее быстро и эффективно – поможет Python."
print(oldtext)
# Out:
# Что такое язык программирования? Это «мостик» между мозгом программиста и компьютера. Языки высокого уровня, к которым относится Python – предполагают, что они ближе к человеческому языку, чем к машинному. В отличие от, например, Ассемблера. А у Python настолько простые и ясные правила, что он приближается к английскому языку. Поэтому часто программирование на языке Python называют «программированием со скоростью мысли». Код на языке Python лаконичен и требует меньше времени на разработку, чем коды на других популярных языках. Самое главное, чтобы у программиста была «мысль» – а осуществить ее быстро и эффективно – поможет Python.

# %%
#давайте поменяем слово Python на Питон и запишем в переменную newtext 

#) 7)тут должна быть строка кода (дополните следующую строку кода) 
newtext = 
#выведите значение переменной newtext
#) 8)тут должна быть строка кода

# %% [markdown]
# Еще одна вещь, которую мы должны разобрать сегодня - это принудительное изменение типа данных в Питон. На лекции мы говорили о строгой типизации данных, те переменная имеет строгий тип данных, которому должны соответствовать все дальнейшие действия с ней. Строки нельзя вычитать, при сложении цифр мы получим новое число, а не склейку и тд. Следующий участок кода Вам нужно простро рассмотреть, чтобы понять разницу между строковыми и числовыми переменными

# %%
variable1 = 5
print(type(variable1))
variable2 = '5'
print(type(variable2))
# Out:
# <class 'int'>
# <class 'str'>

# %%
#Вот это пример строгой типизации данных, складывать переменные разного типа невозможно
variable1 + variable2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-22413046fd8e> in <module>
# ----> 1 variable1 + variable2
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
#зато тип данных можно менять
#поменяем тип данных второй переменной на int - те числовой 
variable3 = int(variable2)
print(type(variable3))
# Out:
# <class 'int'>

# %%
#Маленькая оговорка, так получится сделать, только если переменная состоит из цифр
int(oldtext)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-74b2d51eae03> in <module>
#       1 #Маленькая оговорка, так получится сделать, только если переменная состоит из цифр
# ----> 2 int(oldtext)
#
# ValueError: invalid literal for int() with base 10: 'Что такое язык программирования? Это «мостик» между мозгом программиста и компьютера. Языки высокого уровня, к которым относится Python – предполагают, что они ближе к человеческому языку, чем к маши

# %% [markdown]
# <b>Задание 4</b>

# %%
#поменяйте тип переменной variable1 на строковый и перезапишите ее в переменную variable4

#) 9) тут должна быть строка кода (измените следующию строку кода)
variable4 = variable1

assert (type(variable4) == str), "Вы не поменяли тип данных"

# %% [markdown]
# <b>Задание 5</b>
# А вот и полностью самостоятельное задание.
# <br>
# <br>1) Найдите в интернете определение интерпритатора и компилятора. Объявите новую текстовую переменную и объявите ее
# <br>2) Выведите значение полученной переменной
# <br>3) Выведите ее тип
# <br>4) В тексте замените все буквы 'а' на '1', перезапишите значение переменной
# <br>5) Выведите получившийся текст
# <br>6) А теперь верните все на свои места и снова перезапишите значение переменной
# <br>7) Выведите получившийся текст

# %%
# 10) тут много строк с решением пятого задания
